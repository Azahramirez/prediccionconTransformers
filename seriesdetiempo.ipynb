# %%
# %%bash
# mkdir jena_climate
# cd jena_climate
# wget https://s3.amazonaws.com/keras-datasets/jena_climate_2009_2016.csv.zip
# unzip jena_climate_2009_2016.csv.zip
# Out:
# --2025-04-14 22:16:07--  https://s3.amazonaws.com/keras-datasets/jena_climate_2009_2016.csv.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 54.231.223.24, 52.216.222.96, 52.216.251.86, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|54.231.223.24|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13565642 (13M) [application/zip]
# Saving to: ‘jena_climate_2009_2016.csv.zip’
#
#      0K .......... .......... .......... .......... ..........  0%  897K 15s
#     50K .......... .......... .......... .......... ..........  0%  853K 15s
#    100K .......... .......... .......... .......... ..........  1%  126M 10s
#    150K .......... .......... .......... .......... ..........  1%  927K 11s
#    200K .......... .......... .......... .......... ..........  1%  106M 9s
#    250K .......... .......... .......... .......... ..........  2%  114M 7s
#    300K .......... .......... .......... .......... ..........  2%  868K 8s
#    350K .......... .......... .......... .......... ..........  3%  109M 7s
#    400K .......... .......... .......... .......... ..........  3%  108M 6s
#    450K .......... .......... .......... .......... ..........  3%  129M 6s
#    500K .......... .......... .......... .......... ..........  4% 4.56M 6s
#    550K .......... .......... .......... .......... ..........  4%  132M 5s
#    600K .......... .......... .......... .......... ..........  4% 1.07M 6s
#    650K .......... .......... .......... .......... ..........  5% 9.82M 5s
#    700K .......... .......... .......... .......... ..........  5% 48.8M 5s
#    750K .......... .......... .......... .......... ..........  6% 40.7M 5s
#    800K .......... .......... .......... .......... ..........  6%  153M 4s
#    850K .......... .......... .......... .......... ..........  6%  154M 4s
#    900K .......... .......... .......... .......... ..........  7%  176M 4s
#    950K .......... .......... .......... .......... ..........  7%  149M 4s
#   1000K .......... .......... .......... .......... ..........  7%  153M 3s
#   1050K .......... .......... .......... .......... ..........  8% 1.14M 4s
#   1100K .......... .......... .......... .......... ..........  8% 9.60M 4s
#   1150K .......... .......... .......... .......... ..........  9% 15.0M 3s
#   1200K .......... .......... .......... .......... ..........  9% 18.5M 3s
#   1250K .......... .......... .......... .......... ..........  9% 56.4M 3s
#   1300K .......... .......... .......... .......... .......... 10% 47.3M 3s
#   1350K .......... .......... .......... .......... .......... 10% 23.3M 3s
#   1400K .......... .......... .......... .......... .......... 10% 12.6M 3s
#   1450K .......... .......... .......... .......... .......... 11% 18.2M 3s
#   1500K .......... .......... .......... .......... .......... 11% 16.7M 3s
#   1550K .......... .......... .......... .......... .......... 12% 19.4M 3s
#   1600K .......... .......... .......... .......... .......... 12% 25.7M 3s
#   1650K .......... .......... .......... .......... .......... 12% 13.0M 3s
#   1700K .......... .......... .......... .......... .......... 13%  100M 2s
#   1750K .......... .......... .......... .......... .......... 13% 34.2M 2s
#   1800K .......... .......... .......... .......... .......... 13% 34.6M 2s
#   1850K .......... .......... .......... .......... .......... 14% 53.7M 2s
#   1900K .......... .......... .......... .......... .......... 14%  162M 2s
#   1950K .......... .......... .......... .......... .......... 15% 16.4M 2s
#   2000K .......... .......... .......... .......... .......... 15% 17.4M 2s
#   2050K .......... .......... .......... .......... .......... 15% 24.7M 2s
#   2100K .......... .......... .......... .......... .......... 16% 5.40M 2s
#   2150K .......... .......... .......... .......... .......... 16% 17.8M 2s
#   2200K .......... .......... .......... .......... .......... 16% 32.6M 2s
#   2250K .......... .......... .......... .......... .......... 17% 9.27M 2s
#   2300K .......... .......... .......... .......... .......... 17% 81.5M 2s
#   2350K .......... .......... .......... .......... .......... 18%  152M 2s
#   2400K .......... .......... .......... .......... .......... 18%  105M 2s
#   2450K .......... .......... .......... .......... .......... 18%  170M 2s
#   2500K .......... .......... .......... .......... .......... 19% 6.09M 2s
#   2550K .......... .......... .......... .......... .......... 19% 15.8M 2s
#   2600K .......... .......... .......... .......... .......... 20% 30.7M 2s
#   2650K .......... .......... .......... .......... .......... 20% 14.2M 2s
#   2700K .......... .......... .......... .......... .......... 20% 16.1M 2s
#   2750K .......... .......... .......... .......... .......... 21% 26.8M 2s
#   2800K .......... .......... .......... .......... .......... 21% 20.0M 2s
#   2850K .......... .......... .......... .......... .......... 21%  150M 2s
#   2900K .......... .......... .......... .......... .......... 22% 23.9M 1s
#   2950K .......... .......... .......... .......... .......... 22% 12.0M 1s
#   3000K .......... .......... .......... .......... .......... 23% 13.7M 1s
#   3050K .......... .......... .......... .......... .......... 23% 24.7M 1s
#   3100K .......... .......... .......... .......... .......... 23% 12.9M 1s
#   3150K .......... .......... .......... .......... .......... 24%  102M 1s
#   3200K .......... .......... .......... .......... .......... 24%  164M 1s
#   3250K .......... .......... .......... .......... .......... 24% 12.0M 1s
#   3300K .......... .......... .......... .......... .......... 25% 15.8M 1s
#   3350K .......... .......... .......... .......... .......... 25% 11.4M 1s
#   3400K .......... .......... .......... .......... .......... 26% 16.5M 1s
#   3450K .......... .......... .......... .......... .......... 26% 16.9M 1s
#   3500K .......... .......... .......... .......... .......... 26% 13.1M 1s
#   3550K .......... .......... .......... .......... .......... 27% 52.8M 1s
#   3600K .......... .......... .......... .......... .......... 27% 11.0M 1s
#   3650K .......... .......... .......... .......... .......... 27% 69.1M 1s
#   3700K .......... .......... .......... .......... .......... 28%  169M 1s
#   3750K .......... .......... .......... .......... .......... 28%  213M 1s
#   3800K .......... .......... .......... .......... .......... 29%  207M 1s
#   3850K .......... .......... .......... .......... .......... 29%  219M 1s
#   3900K .......... .......... .......... .......... .......... 29% 10.4M 1s
#   3950K .......... .......... .......... .......... .......... 30% 21.4M 1s
#   4000K .......... .......... .......... .......... .......... 30% 18.3M 1s
#   4050K .......... .......... .......... .......... .......... 30% 33.3M 1s
#   4100K .......... .......... .......... .......... .......... 31% 13.1M 1s
#   4150K .......... .......... .......... .......... .......... 31% 24.1M 1s
#   4200K .......... .......... .......... .......... .......... 32% 29.8M 1s
#   4250K .......... .......... .......... .......... .......... 32% 25.3M 1s
#   4300K .......... .......... .......... .......... .......... 32% 20.4M 1s
#   4350K .......... .......... .......... .......... .......... 33% 22.5M 1s
#   4400K .......... .......... .......... .......... .......... 33% 22.6M 1s
#   4450K .......... .......... .......... .......... .......... 33%  188M 1s
#   4500K .......... .......... .......... .......... .......... 34%  162M 1s
#   4550K .......... .......... .......... .......... .......... 34%  184M 1s
#   4600K .......... .......... .......... .......... .......... 35% 7.09M 1s
#   4650K .......... .......... .......... .......... .......... 35% 49.3M 1s
#   4700K .......... .......... .......... .......... .......... 35% 18.7M 1s
#   4750K .......... .......... .......... .......... .......... 36% 14.3M 1s
#   4800K .......... .......... .......... .......... .......... 36%  127M 1s
#   4850K .......... .......... .......... .......... .......... 36% 25.8M 1s
#   4900K .......... .......... .......... .......... .......... 37% 26.8M 1s
#   4950K .......... .......... .......... .......... .......... 37%  199M 1s
#   5000K .......... .......... .......... .......... .......... 38%  206M 1s
#   5050K .......... .......... .......... .......... .......... 38%  197M 1s
#   5100K .......... .......... .......... .......... .......... 38%  165M 1s
#   5150K .......... .......... .......... .......... .......... 39% 9.42M 1s
#   5200K .......... .......... .......... .......... .......... 39%  102M 1s
#   5250K .......... .......... .......... .......... .......... 40% 28.6M 1s
#   5300K .......... .......... .......... .......... .......... 40% 27.7M 1s
#   5350K .......... .......... .......... .......... .......... 40% 34.6M 1s
#   5400K .......... .......... .......... .......... .......... 41% 28.4M 1s
#   5450K .......... .......... .......... .......... .......... 41% 29.4M 1s
#   5500K .......... .......... .......... .......... .......... 41% 22.3M 1s
#   5550K .......... .......... .......... .......... .......... 42% 31.8M 1s
#   5600K .......... .......... .......... .......... .......... 42% 21.9M 1s
#   5650K .......... .......... .......... .......... .......... 43% 21.9M 1s
#   5700K .......... .......... .......... .......... .......... 43% 33.1M 1s
#   5750K .......... .......... .......... .......... .......... 43% 33.9M 1s
#   5800K .......... .......... .......... .......... .......... 44% 75.9M 1s
#   5850K .......... .......... .......... .......... .......... 44% 31.7M 1s
#   5900K .......... .......... .......... .......... .......... 44% 29.3M 1s
#   5950K .......... .......... .......... .......... .......... 45% 19.3M 1s
#   6000K .......... .......... .......... .......... .......... 45%  126M 1s
#   6050K .......... .......... .......... .......... .......... 46% 33.7M 1s
#   6100K .......... .......... .......... .......... .......... 46% 39.1M 1s
#   6150K .......... .......... .......... .......... .......... 46% 48.3M 1s
#   6200K .......... .......... .......... .......... .......... 47%  215M 1s
#   6250K .......... .......... .......... .......... .......... 47%  203M 1s
#   6300K .......... .......... .......... .......... .......... 47% 14.2M 1s
#   6350K .......... .......... .......... .......... .......... 48% 17.0M 1s
#   6400K .......... .......... .......... .......... .......... 48% 25.0M 1s
#   6450K .......... .......... .......... .......... .......... 49% 82.0M 1s
#   6500K .......... .......... .......... .......... .......... 49% 33.7M 1s
#   6550K .......... .......... .......... .......... .......... 49% 18.0M 1s
#   6600K .......... .......... .......... .......... .......... 50% 28.9M 1s
#   6650K .......... .......... .......... .......... .......... 50% 34.8M 1s
#   6700K .......... .......... .......... .......... .......... 50%  168M 1s
#   6750K .......... .......... .......... .......... .......... 51%  218M 1s
#   6800K .......... .......... .......... .......... .......... 51%  220M 1s
#   6850K .......... .......... .......... .......... .......... 52%  222M 1s
#   6900K .......... .......... .......... .......... .......... 52% 12.4M 1s
#   6950K .......... .......... .......... .......... .......... 52% 25.5M 1s
#   7000K .......... .......... .......... .......... .......... 53% 75.6M 1s
#   7050K .......... .......... .......... .......... .......... 53% 27.4M 1s
#   7100K .......... .......... .......... .......... .......... 53% 31.4M 0s
#   7150K .......... .......... .......... .......... .......... 54% 44.2M 0s
#   7200K .......... .......... .......... .......... .......... 54% 30.8M 0s
#   7250K .......... .......... .......... .......... .......... 55% 17.6M 0s
#   7300K .......... .......... .......... .......... .......... 55% 15.7M 0s
#   7350K .......... .......... .......... .......... .......... 55% 98.9M 0s
#   7400K .......... .......... .......... .......... .......... 56%  109M 0s
#   7450K .......... .......... .......... .......... .......... 56% 38.0M 0s
#   7500K .......... .......... .......... .......... .......... 56% 21.7M 0s
#   7550K .......... .......... .......... .......... .......... 57% 50.6M 0s
#   7600K .......... .......... .......... .......... .......... 57% 12.0M 0s
#   7650K .......... .......... .......... .......... .......... 58%  123M 0s
#   7700K .......... .......... .......... .......... .......... 58% 54.9M 0s
#   7750K .......... .......... .......... .......... .......... 58% 24.4M 0s
#   7800K .......... .......... .......... .......... .......... 59%  135M 0s
#   7850K .......... .......... .......... .......... .......... 59% 30.1M 0s
#   7900K .......... .......... .......... .......... .......... 60% 15.3M 0s
#   7950K .......... .......... .......... .......... .......... 60% 57.7M 0s
#   8000K .......... .......... .......... .......... .......... 60%  222M 0s
#   8050K .......... .......... .......... .......... .......... 61%  212M 0s
#   8100K .......... .......... .......... .......... .......... 61%  171M 0s
#   8150K .......... .......... .......... .......... .......... 61% 9.93M 0s
#   8200K .......... .......... .......... .......... .......... 62% 17.3M 0s
#   8250K .......... .......... .......... .......... .......... 62% 27.6M 0s
#   8300K .......... .......... .......... .......... .......... 63% 26.7M 0s
#   8350K .......... .......... .......... .......... .......... 63% 35.1M 0s
#   8400K .......... .......... .......... .......... .......... 63% 32.2M 0s
#   8450K .......... .......... .......... .......... .......... 64% 34.9M 0s
#   8500K .......... .......... .......... .......... .......... 64% 69.0M 0s
#   8550K .......... .......... .......... .......... .......... 64% 59.8M 0s
#   8600K .......... .......... .......... .......... .......... 65% 27.6M 0s
#   8650K .......... .......... .......... .......... .......... 65% 31.2M 0s
#   8700K .......... .......... .......... .......... .......... 66% 23.8M 0s
#   8750K .......... .......... .......... .......... .......... 66% 36.5M 0s
#   8800K .......... .......... .......... .......... .......... 66%  103M 0s
#   8850K .......... .......... .......... .......... .......... 67%  210M 0s
#   8900K .......... .......... .......... .......... .......... 67%  113M 0s
#   8950K .......... .......... .......... .......... .......... 67% 14.8M 0s
#   9000K .......... .......... .......... .......... .......... 68% 33.0M 0s
#   9050K .......... .......... .......... .......... .......... 68% 30.4M 0s
#   9100K .......... .......... .......... .......... .......... 69% 26.9M 0s
#   9150K .......... .......... .......... .......... .......... 69% 63.0M 0s
#   9200K .......... .......... .......... .......... .......... 69%  120M 0s
#   9250K .......... .......... .......... .......... .......... 70% 55.6M 0s
#   9300K .......... .......... .......... .......... .......... 70% 24.6M 0s
#   9350K .......... .......... .......... .......... .......... 70% 32.2M 0s
#   9400K .......... .......... .......... .......... .......... 71% 25.0M 0s
#   9450K .......... .......... .......... .......... .......... 71% 32.7M 0s
#   9500K .......... .......... .......... .......... .......... 72% 89.7M 0s
#   9550K .......... .......... .......... .......... .......... 72% 47.3M 0s
#   9600K .......... .......... .......... .......... .......... 72% 44.8M 0s
#   9650K .......... .......... .......... .......... .......... 73% 38.3M 0s
#   9700K .......... .......... .......... .......... .......... 73% 17.5M 0s
#   9750K .......... .......... .......... .......... .......... 73% 41.8M 0s
#   9800K .......... .......... .......... .......... .......... 74% 75.7M 0s
#   9850K .......... .......... .......... .......... .......... 74% 23.7M 0s
#   9900K .......... .......... .......... .......... .......... 75% 34.1M 0s
#   9950K .......... .......... .......... .......... .......... 75%  181M 0s
#  10000K .......... .......... .......... .......... .......... 75%  186M 0s
#  10050K .......... .......... .......... .......... .......... 76% 30.9M 0s
#  10100K .......... .......... .......... .......... .......... 76% 26.0M 0s
#  10150K .......... .......... .......... .......... .......... 76% 28.5M 0s
#  10200K .......... .......... .......... .......... .......... 77% 39.1M 0s
#  10250K .......... .......... .......... .......... .......... 77% 46.0M 0s
#  10300K .......... .......... .......... .......... .......... 78% 15.8M 0s
#  10350K .......... .......... .......... .......... .......... 78% 66.8M 0s
#  10400K .......... .......... .......... .......... .......... 78% 64.4M 0s
#  10450K .......... .......... .......... .......... .......... 79% 8.60M 0s
#  10500K .......... .......... .......... .......... .......... 79%  120M 0s
#  10550K .......... .......... .......... .......... .......... 80%  128M 0s
#  10600K .......... .......... .......... .......... .......... 80% 23.6M 0s
#  10650K .......... .......... .......... .......... .......... 80% 29.4M 0s
#  10700K .......... .......... .......... .......... .......... 81% 27.2M 0s
#  10750K .......... .......... .......... .......... .......... 81% 18.5M 0s
#  10800K .......... .......... .......... .......... .......... 81%  138M 0s
#  10850K .......... .......... .......... .......... .......... 82% 9.85M 0s
#  10900K .......... .......... .......... .......... .......... 82%  102M 0s
#  10950K .......... .......... .......... .......... .......... 83% 50.1M 0s
#  11000K .......... .......... .......... .......... .......... 83% 22.8M 0s
#  11050K .......... .......... .......... .......... .......... 83% 16.9M 0s
#  11100K .......... .......... .......... .......... .......... 84% 18.5M 0s
#  11150K .......... .......... .......... .......... .......... 84%  126M 0s
#  11200K .......... .......... .......... .......... .......... 84% 16.8M 0s
#  11250K .......... .......... .......... .......... .......... 85% 76.0M 0s
#  11300K .......... .......... .......... .......... .......... 85% 10.0M 0s
#  11350K .......... .......... .......... .......... .......... 86%  126M 0s
#  11400K .......... .......... .......... .......... .......... 86%  179M 0s
#  11450K .......... .......... .......... .......... .......... 86%  217M 0s
#  11500K .......... .......... .......... .......... .......... 87%  186M 0s
#  11550K .......... .......... .......... .......... .......... 87% 9.34M 0s
#  11600K .......... .......... .......... .......... .......... 87% 10.7M 0s
#  11650K .......... .......... .......... .......... .......... 88%  136M 0s
#  11700K .......... .......... .......... .......... .......... 88%  114M 0s
#  11750K .......... .......... .......... .......... .......... 89% 29.2M 0s
#  11800K .......... .......... .......... .......... .......... 89% 18.2M 0s
#  11850K .......... .......... .......... .......... .......... 89% 28.4M 0s
#  11900K .......... .......... .......... .......... .......... 90% 16.9M 0s
#  11950K .......... .......... .......... .......... .......... 90%  106M 0s
#  12000K .......... .......... .......... .......... .......... 90% 34.0M 0s
#  12050K .......... .......... .......... .......... .......... 91% 12.3M 0s
#  12100K .......... .......... .......... .......... .......... 91%  187M 0s
#  12150K .......... .......... .......... .......... .......... 92%  220M 0s
#  12200K .......... .......... .......... .......... .......... 92%  217M 0s
#  12250K .......... .......... .......... .......... .......... 92%  199M 0s
#  12300K .......... .......... .......... .......... .......... 93%  179M 0s
#  12350K .......... .......... .......... .......... .......... 93%  216M 0s
#  12400K .......... .......... .......... .......... .......... 93%  210M 0s
#  12450K .......... .......... .......... .......... .......... 94% 5.48M 0s
#  12500K .......... .......... .......... .......... .......... 94% 38.5M 0s
#  12550K .......... .......... .......... .......... .......... 95% 34.1M 0s
#  12600K .......... .......... .......... .......... .......... 95% 28.6M 0s
#  12650K .......... .......... .......... .......... .......... 95% 12.7M 0s
#  12700K .......... .......... .......... .......... .......... 96% 98.2M 0s
#  12750K .......... .......... .......... .......... .......... 96% 30.9M 0s
#  12800K .......... .......... .......... .......... .......... 96% 21.4M 0s
#  12850K .......... .......... .......... .......... .......... 97% 12.7M 0s
#  12900K .......... .......... .......... .......... .......... 97%  115M 0s
#  12950K .......... .......... .......... .......... .......... 98% 34.5M 0s
#  13000K .......... .......... .......... .......... .......... 98% 14.9M 0s
#  13050K .......... .......... .......... .......... .......... 98% 25.3M 0s
#  13100K .......... .......... .......... .......... .......... 99% 31.1M 0s
#  13150K .......... .......... .......... .......... .......... 99% 20.9M 0s
#  13200K .......... .......... .......... .......... .......   100%  136M=0.8s
#
# 2025-04-14 22:16:09 (16.6 MB/s) - ‘jena_climate_2009_2016.csv.zip’ saved [13565642/13565642]
# Archive:  jena_climate_2009_2016.csv.zip
#   inflating: jena_climate_2009_2016.csv
#   inflating: __MACOSX/._jena_climate_2009_2016.csv

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# 2025-04-14 22:16:56.971798: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-14 22:16:56.975245: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-14 22:16:56.982107: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744669016.995201   22186 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744669016.999442   22186 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1744669017.011897   22186 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744669017.011909   22186 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744669017.011911   22186 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744669017.011912   22186 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-14 22:16:57.016156: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
data_dir = 'jena_climate'
fname = os.path.join(data_dir, "jena_climate_2009_2016.csv")

with open(fname) as f:
    data = f.read()

lines = data.split("\n")
header = lines[0].split(",")
lines = lines[1:]
print(header)
print(len(lines))
# Out:
# ['"Date Time"', '"p (mbar)"', '"T (degC)"', '"Tpot (K)"', '"Tdew (degC)"', '"rh (%)"', '"VPmax (mbar)"', '"VPact (mbar)"', '"VPdef (mbar)"', '"sh (g/kg)"', '"H2OC (mmol/mol)"', '"rho (g/m**3)"', '"wv (m/s)"', '"max. wv (m/s)"', '"wd (deg)"']
# 420451

# %%
temperature = np.zeros((len(lines),))
for i, line in enumerate(lines):
    values = [float(x) for x in line.split(",")[1:]]
    temperature[i] = values[1]

# %%
num_train_samples = int(0.5 * len(temperature))
num_val_samples = int(0.25 * len(temperature))
num_test_samples = len(temperature) - num_train_samples - num_val_samples
print("num_train_samples:", num_train_samples)
print("num_val_samples:", num_val_samples)
print("num_test_samples:", num_test_samples)
# Out:
# num_train_samples: 210225
# num_val_samples: 105112
# num_test_samples: 105114

# %%
sampling_rate = 6
sequence_length = 120
delay = sampling_rate * (sequence_length + 24 - 1)
batch_size = 256

train_dataset = keras.utils.timeseries_dataset_from_array(
    temperature[:-delay],
    targets=temperature[delay:],
    sampling_rate=sampling_rate,
    sequence_length=sequence_length,
    shuffle=True,
    batch_size=batch_size,
    start_index=0,
    end_index=num_train_samples)

val_dataset = keras.utils.timeseries_dataset_from_array(
    temperature[:-delay],
    targets=temperature[delay:],
    sampling_rate=sampling_rate,
    sequence_length=sequence_length,
    shuffle=True,
    batch_size=batch_size,
    start_index=num_train_samples,
    end_index=num_train_samples + num_val_samples)

test_dataset = keras.utils.timeseries_dataset_from_array(
    temperature[:-delay],
    targets=temperature[delay:],
    sampling_rate=sampling_rate,
    sequence_length=sequence_length,
    shuffle=True,
    batch_size=batch_size,
    start_index=num_train_samples + num_val_samples)
# Out:
# 2025-04-14 22:30:46.012324: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Attention and Normalization
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(inputs, inputs)
    x = layers.Dropout(dropout)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(res)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    return x + res

def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_last")(x)
    for dim in mlp_units:
        x = layers.Dense(1)(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(1)(x)
    return keras.Model(inputs, outputs)

# %%
input_shape =(sequence_length,1)

model = build_model(
    input_shape,
    head_size=64,
    num_heads=1,
    ff_dim=4,
    num_transformer_blocks=2,
    mlp_units=[128],
    mlp_dropout=0.4,
    dropout=0.25,
)

model.compile(
    loss="mse",
    optimizer="rmsprop",
    metrics=["mae"],
)
model.summary()

callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]

model.fit(
    train_dataset,
    epochs=5,
    batch_size=128,
    callbacks=callbacks,
    validation_data=val_dataset
)

model.evaluate(test_dataset, verbose=1)
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5       │ (None, 120, 1)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 120, 1)    │        449 │ input_layer_5[0]… │
# │ (MultiHeadAttentio… │                   │            │ input_layer_5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_22          │ (None, 120, 1)    │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 120, 1)    │          2 │ dropout_22[0][0]  │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 120, 1)    │          0 │ layer_normalizat… │
# │                     │                   │            │ input_layer_5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_15 (Conv1D)  │ (None, 120, 4)    │          8 │ add_12[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_23          │ (None, 120, 4)    │          0 │ conv1d_15[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_16 (Conv1D)  │ (None, 120, 1)    │          5 │ dropout_23[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 120, 1)    │          2 │ conv1d_16[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 120, 1)    │          0 │ layer_normalizat… │
# │                     │                   │            │ add_12[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 120, 1)    │        449 │ add_13[0][0],     │
# │ (MultiHeadAttentio… │                   │            │ add_13[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_25          │ (None, 120, 1)    │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 120, 1)    │          2 │ dropout_25[0][0]  │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 120, 1)    │          0 │ layer_normalizat… │
# │                     │                   │            │ add_13[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_17 (Conv1D)  │ (None, 120, 4)    │          8 │ add_14[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_26          │ (None, 120, 4)    │          0 │ conv1d_17[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_18 (Conv1D)  │ (None, 120, 1)    │          5 │ dropout_26[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 120, 1)    │          2 │ conv1d_18[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 120, 1)    │          0 │ layer_normalizat… │
# │                     │                   │            │ add_14[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1)         │          0 │ add_15[0][0]      │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 1)         │          2 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_27          │ (None, 1)         │          0 │ dense_7[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 1)         │          2 │ dropout_27[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 936 (3.66 KB)
#  Trainable params: 936 (3.66 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/5
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 241s 291ms/step - loss: 198.8653 - mae: 11.5929 - val_loss: 75.2316 - val_mae: 7.0195
# Epoch 2/5
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 263s 292ms/step - loss: 72.1980 - mae: 6.3861 - val_loss: 39.4682 - val_mae: 4.8959
# Epoch 3/5
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 278s 339ms/step - loss: 64.3256 - mae: 5.9970 - val_loss: 37.6705 - val_mae: 4.7763
# Epoch 4/5
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 243s 296ms/step - loss: 59.6863 - mae: 5.8104 - val_loss: 35.4510 - val_mae: 4.6288
# Epoch 5/5
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 259s 293ms/step - loss: 56.4392 - mae: 5.6774 - val_loss: 33.4996 - val_mae: 4.5000
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 44s 108ms/step - loss: 35.9959 - mae: 4.5875
# [35.940895080566406, 4.595857620239258]

# %%
model.save('transformer.keras')

# %%
first_10min_indices = np.arange(0, 5 * 144, 144)
temperature[first_10min_indices]
# Out:
# array([-8.02, -4.6 , -4.89, -1.83, -1.5 ])

# %%
model.predict()
